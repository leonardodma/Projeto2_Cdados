# %% [markdown]
# # Integrentes:
#
# * `Andresa Bicudo`
# * `Gabriel Yamashita`
# * `Leonardo Malta`

# %% [markdown]
# # Objetivo:
# O objetivo desse projeto é construir um classificador que determina se o Leonardo Malta gostará ou não de uma música, com base em seu histórico de exibição do Spotify e em sua classificação.

# %% [markdown]
# # Separação dos Dados:

# %%
# Importanto Bibliotecas para o Trabalho:
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.api as sm

import scipy as scp
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
dados = pd.read_excel('classificacao_musicas_leonardo.xlsx')
dados.head(5)
# Out:
#                                 name  like  danceability  energy  key  \
# 0                         Ouvi Dizer     1         0.641   0.614    7
# 1     Pain 1993 (with Playboi Carti)     0         0.825   0.373    5
# 2                     Sentimento Bom     0         0.780   0.607    9
# 3                           All Star     2         0.512   0.391    9
# 4  Contrato de RenovaÃ§Ã£o - Ao Vivo     1         0.577   0.752    9
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.847     1       0.0532        0.0745          0.000000     0.093
# 1    -5.532     0       0.1080        0.1630          0.000000     0.368
# 2    -6.440     1       0.0864        0.2060          0.000016     0.440
# 3   -10.400     1       0.0492        0.8890          0.000003     0.714
# 4    -7.447     1       0.0654        0.7290          0.000000     0.929
#
#    valence    tempo                      id  \
# 0    0.727   81.011  1qCLx3nX25NuhfPjM5E1qV
# ...

# %%
dados['like'].value_counts()
# Out:
# 2    366
# 1    288
# 0    222
# Name: like, dtype: int64

# %%
hate = dados.loc[dados['like'] == 0, :]
like = dados.loc[dados['like'] == 1, :]
love = dados.loc[dados['like'] == 2, :]

# %% [markdown]
# # Criando Gráficos Comparativos

# %%
# Funçção para cirar histogramas em loop
def Hist(variavel, df1, df2, df3):
    plt.style.use('bmh')
    sns.distplot(df1[variavel], color="darksalmon", label="Hate")
    sns.distplot(df2[variavel], color="skyblue", label="Like")
    sns.distplot(df3[variavel], color="lightgreen", label="Love")
    plt.legend(loc='best')
    plt.ylabel('densidade')
    plt.xlabel(variavel)


features = [
    'danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness',
    'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms'
]

plt.figure(figsize=(20, 40))

for i in range(len(features)):
    plt.subplot(6, 2, i + 1)
    Hist(features[i], hate, like, love)

# %% [markdown]
# # Considerações do Modelo
#
# Por meio da análise dos histogramas, foi possível concluir que as varáveis que mais tiveram divergência foram:
# * danceability
# * energy
# * loudness
# * speechiness
# * liveness
# * tempo
#
# Assim, essas srão as variáveis que serão utilizadas para a modelagem e aprofundamento do classificador.

# %% [markdown]
# # Regressão Logística Multinomial

# %% [markdown]
# #### SKYLEARN

# %%
x_train = dados.drop([
    'like', 'name', 'key', 'acousticness', 'instrumentalness', 'valence', 'id',
    'uri', 'track_href', 'analysis_url', 'time_signature', 'mode',
    'duration_ms'
],
                     axis=1)

x_train.head(3)
# Out:
#    danceability  energy  loudness  speechiness  liveness    tempo
# 0         0.641   0.614    -7.847       0.0532     0.093   81.011
# 1         0.825   0.373    -5.532       0.1080     0.368   77.271
# 2         0.780   0.607    -6.440       0.0864     0.440  130.076

# %%
y_train = dados['like']

model1 = LogisticRegression(random_state=0,
                             multi_class='multinomial',
                             penalty='none',
                             solver='newton-cg').fit(x_train, y_train)
#preds = model1.predict(x_test)
params = model1.get_params()
print(params)
# Out:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'multinomial', 'n_jobs': None, 'penalty': 'none', 'random_state': 0, 'solver': 'newton-cg', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}

# %%
print('Intercept: \n', model1.intercept_)
print('Coefficients: \n', model1.coef_)
# Out:
# Intercept:
#  [-0.22079828 -0.88584617  1.10664446]
# Coefficients:
#  [[-8.52753333e-01  3.88913664e-01 -5.12675425e-02  1.85149201e+00
#   -1.08866493e+00  7.50177655e-05]
#  [ 8.87192527e-01  3.23229641e-01  3.27528811e-02  2.25347541e-01
#    3.64163658e-01  1.90007116e-03]
#  [-3.44391940e-02 -7.12143305e-01  1.85146614e-02 -2.07683955e+00
#    7.24501272e-01 -1.97508893e-03]]

# %%
# The actual output is log(p(y=c)/1 - p(y=c)), which are multinomial logit coefficients, 
# hence the three equations.

#Calculate odds ratio estimates
np.exp(model1.coef_)
# Out:
# array([[0.42623974, 1.47537717, 0.95002446, 6.36931553, 0.33666567,
#         1.00007502],
#        [2.42830268, 1.38158258, 1.03329516, 1.25275802, 1.43930975,
#         1.00190188],
#        [0.96614709, 0.49059158, 1.01868712, 0.12532567, 2.06370162,
#         0.99802686]])

# %% [markdown]
# #### STATSMODELS

# %%
important_features = list(x_train.columns.values)

# Teste 
def Box(variavel, df):
    #plt.style.use('bmh')
    df.boxplot(column=variavel, by='like')
    #plt.scatter(df[variavel], df['like'], marker='+', color="skyblue")
    plt.ylabel('distribuição')
    plt.xlabel(variavel)


# usar box plot
plt.figure(figsize=(20, 20))

for i in range(len(important_features)):
    #plt.subplot(4, 2, i + 1)
    Box(important_features[i], dados)

plt.show()
